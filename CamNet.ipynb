# %%
# !unzip "/content/CAMANet-main.zip"
# Out:
# Archive:  /content/CAMANet-main.zip
# 3f316f10a608d4dae5e2e2e1981d66218f5f3b6b
#    creating: CAMANet-main/
#   inflating: CAMANet-main/.gitignore
#   inflating: CAMANet-main/README.md
#   inflating: CAMANet-main/architecture.png
#   inflating: CAMANet-main/cam_vis.py
#   inflating: CAMANet-main/config_swin.py
#    creating: CAMANet-main/configs/
#   inflating: CAMANet-main/configs/swin_base_patch4_window12_384_22kto1k_finetune.yaml
#   inflating: CAMANet-main/configs/swin_base_patch4_window12_384_finetune.yaml
#   inflating: CAMANet-main/configs/swin_base_patch4_window7_224.yaml
#   inflating: CAMANet-main/configs/swin_base_patch4_window7_224_22k.yaml
#   inflating: CAMANet-main/configs/swin_base_patch4_window7_224_22kto1k_finetune.yaml
#   inflating: CAMANet-main/configs/swin_large_patch4_window12_384_22kto1k_finetune.yaml
#   inflating: CAMANet-main/configs/swin_large_patch4_window7_224_22k.yaml
# ...

# %%
# Out:
# Archive:  /content/iu_xray.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/iu_xray.zip or
#         /content/iu_xray.zip.zip, and cannot find /content/iu_xray.zip.ZIP, period.

# %%
# Install PyTorch 1.6 and Torchvision
# !pip install torch==1.6.0 torchvision==0.7.0

# Clone the pycocoevalcap repository
# !git clone https://github.com/salaniz/pycocoevalcap.git

# Install dependencies for pycocoevalcap
# !pip install cython
# !pip install git+https://github.com/tylin/coco-caption.git

# Install pycocoevalcap
# %cd pycocoevalcap
# !python setup.py install
# %cd ..
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.6.0 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1)
# ERROR: No matching distribution found for torch==1.6.0
# Cloning into 'pycocoevalcap'...
# remote: Enumerating objects: 821, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 821 (delta 5), reused 15 (delta 4), pack-reused 797 (from 1)
# Receiving objects: 100% (821/821), 130.06 MiB | 31.20 MiB/s, done.
# Resolving deltas: 100% (424/424), done.
# ...
#   Cloning https://github.com/tylin/coco-caption.git to /tmp/pip-req-build-zvzmixch
#   Running command git clone --filter=blob:none --quiet https://github.com/tylin/coco-caption.git /tmp/pip-req-build-zvzmixch
#   Resolved https://github.com/tylin/coco-caption.git to commit 3a9afb2682141a03e1cdc02b0df6770d2c884f6f
# ...

# %%
pip install yacs

# %%
pip install ml_collections
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.4 MB/s eta 0:00:00
# ...

# %%
pip install torchcam
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir("/content/CAMANet-main/")
print(os.getcwd())
# Out:
# /content/CAMANet-main

# %%
# !python main.py \
--label_path /content/CAMANet-main/labels/labels.json \
--dataset_name iu_xray \
--max_seq_length 60 \
--threshold 3 \
--batch_size 32 \
--epochs 30 \
--lr_ve 1e-3 \
--lr_ed 2e-3 \
--save_dir /content/CAMANet-main/results/iu_xray \
--ve_name densenet121 \
--ed_name r2gen \
--cfg /content/CAMANet-main/configs/swin_tiny_patch4_window7_224.yaml \
--early_stop 10 \
--weight_decay 5e-5 \
--optim Adam \
--decay_epochs 50 \
--warmup_epochs 0 \
--warmup_lr 1e-4 \
--lr_scheduler step \
--decay_rate 0.8 \
--seed 2401 \
--addcls  \
--cls_w 1 \
--fbl \
--attn_cam \
--attn_method max \
--topk 0.25 \
--layer_id 2 \
--mse_w 0.15 \
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2024-11-14 09:02:20.328904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-14 09:02:20.363120: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-14 09:02:20.378764: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
